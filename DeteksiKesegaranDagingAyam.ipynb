# %%
# !pip install mega.py
# Out:
# Collecting mega.py
#   Downloading mega.py-1.0.8-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=0.10 in /usr/local/lib/python3.10/dist-packages (from mega.py) (2.31.0)
# Collecting pycryptodome<4.0.0,>=3.9.6 (from mega.py)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: pathlib==1.0.1 in /usr/local/lib/python3.10/dist-packages (from mega.py) (1.0.1)
# Collecting tenacity<6.0.0,>=5.1.5 (from mega.py)
#   Downloading tenacity-5.1.5-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=0.10->mega.py) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=0.10->mega.py) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=0.10->mega.py) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=0.10->mega.py) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from tenacity<6.0.0,>=5.1.5->mega.py) (1.16.0)
# Installing collected packages: tenacity, pycryptodome, mega.py
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.3
#     Uninstalling tenacity-8.2.3:
#       Successfully uninstalled tenacity-8.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotly 5.15.0 requires tenacity>=6.2.0, but you have tenacity 5.1.5 which is incompatible.
# Successfully installed mega.py-1.0.8 pycryptodome-3.20.0 tenacity-5.1.5

# %%
from mega import Mega
mega = Mega()
m = mega.login()
m.download_url('https://mega.nz/file/pmok3T4T#hm6_2JeXyD31Jei9rfba9EXDSTGBCfmLjX4OWewAbQA')
# Out:
# PosixPath('DAGING AYAM-20240312T143959Z-001.zip')

# %%
import tensorflow as tensor
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import zipfile,os
zip_lcl = '/content/DAGING AYAM-20240312T143959Z-001.zip'
rzip = zipfile.ZipFile(zip_lcl, 'r')
rzip.extractall('/content')
rzip.close()

dirbase = '/content/DAGING AYAM'
dir_latih = os.path.join(dirbase)

# %%
imagesize = 300

# %%
data_latih = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    validation_split=0.2,
    shear_range=0)
data_valid = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    validation_split=0.2,
    shear_range=0)

# %%
generator_latih = data_latih.flow_from_directory(
    directory=dir_latih,
    target_size=(imagesize,imagesize),
    batch_size=100,
    subset='training',
    class_mode='binary')
generator_valid = data_valid.flow_from_directory(
    directory=dir_latih,
    target_size=(imagesize,imagesize),
    batch_size=100,
    subset='validation',
    class_mode='binary')
# Out:
# Found 80 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = tensor.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(imagesize, imagesize, 3))
model.trainable = False

# Menambahkan lapisan Dense di atas model VGG16
top_model = tensor.keras.models.Sequential()
top_model.add(tensor.keras.layers.Flatten(input_shape=model.output_shape[1:]))
top_model.add(tensor.keras.layers.Dense(256, activation='relu'))
top_model.add(tensor.keras.layers.Dense(1, activation='sigmoid'))

model = tensor.keras.models.Model(inputs=model.input, outputs=top_model(model.output))

# Print the summary of the model
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 300, 300, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 300, 300, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 150, 150, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 150, 150, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 150, 150, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 75, 75, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 75, 75, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 75, 75, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 75, 75, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 37, 37, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 18, 18, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  sequential_2 (Sequential)   (None, 1)                 10617345
#
# =================================================================
# Total params: 25332033 (96.63 MB)
# Trainable params: 10617345 (40.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
from tensorflow.keras import metrics

model.compile(loss='binary_crossentropy',
              optimizer=tensor.optimizers.Adam(),
              metrics=['accuracy', metrics.Recall(), metrics.Precision()])

# %%
model_viz = tensor.keras.utils.plot_model(model,
                          to_file='model.png',
                          show_shapes=True,
                          show_layer_names=True,
                          rankdir='TB',
                          expand_nested=True,
                          dpi=55)
model_viz

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

cekmodel = ModelCheckpoint(filepath='model.hdf5',monitor='val_accuracy',mode='max',verbose=2,save_best_only=True)

# %%
class myCallback(tensor.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy') >= 0.972):
      print("\nAkurasi di atas 97%, hentikan training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
history = model.fit(
    generator_latih,
    epochs=100,
    validation_data=generator_valid,
    verbose=2,
    callbacks=[callbacks]
    )
# Out:
# Epoch 1/100
# 1/1 - 26s - loss: 0.8356 - accuracy: 0.5000 - recall_2: 1.0000 - precision_2: 0.5000 - val_loss: 16.7908 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - 26s/epoch - 26s/step
# Epoch 2/100
# 1/1 - 10s - loss: 15.3057 - accuracy: 0.5000 - recall_2: 0.0000e+00 - precision_2: 0.0000e+00 - val_loss: 5.0734 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - 10s/epoch - 10s/step
# Epoch 3/100
# 1/1 - 10s - loss: 4.5133 - accuracy: 0.5000 - recall_2: 0.0000e+00 - precision_2: 0.0000e+00 - val_loss: 4.9158 - val_accuracy: 0.5000 - val_recall_2: 1.0000 - val_precision_2: 0.5000 - 10s/epoch - 10s/step
# Epoch 4/100
# 1/1 - 10s - loss: 5.0725 - accuracy: 0.5000 - recall_2: 1.0000 - precision_2: 0.5000 - val_loss: 5.6864 - val_accuracy: 0.5000 - val_recall_2: 1.0000 - val_precision_2: 0.5000 - 10s/epoch - 10s/step
# Epoch 5/100
# 1/1 - 10s - loss: 5.6772 - accuracy: 0.5000 - recall_2: 1.0000 - precision_2: 0.5000 - val_loss: 3.5336 - val_accuracy: 0.5000 - val_recall_2: 1.0000 - val_precision_2: 0.5000 - 10s/epoch - 10s/step
# Epoch 6/100
# 1/1 - 11s - loss: 2.9768 - accuracy: 0.5000 - recall_2: 1.0000 - precision_2: 0.5000 - val_loss: 1.1493 - val_accuracy: 0.5000 - val_recall_2: 0.1000 - val_precision_2: 0.5000 - 11s/epoch - 11s/step
# Epoch 7/100
# 1/1 - 10s - loss: 0.4367 - accuracy: 0.7875 - recall_2: 0.6000 - precision_2: 0.9600 - val_loss: 3.5662 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - 10s/epoch - 10s/step
# Epoch 8/100
# 1/1 - 11s - loss: 2.4528 - accuracy: 0.5000 - recall_2: 0.0000e+00 - precision_2: 0.0000e+00 - val_loss: 3.4664 - val_accuracy: 0.5000 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - 11s/epoch - 11s/step
# Epoch 9/100
# 1/1 - 12s - loss: 2.0424 - accuracy: 0.5000 - recall_2: 0.0000e+00 - precision_2: 0.0000e+00 - val_loss: 1.8501 - val_accuracy: 0.5000 - val_recall_2: 0.1000 - val_precision_2: 0.5000 - 12s/epoch - 12s/step
# Epoch 10/100
# 1/1 - 10s - loss: 0.6399 - accuracy: 0.6875 - recall_2: 0.4000 - precision_2: 0.9412 - val_loss: 1.0553 - val_accuracy: 0.5000 - val_recall_2: 0.9000 - val_precision_2: 0.5000 - 10s/epoch - 10s/step
# Epoch 11/100
# 1/1 - 10s - loss: 0.4068 - accuracy: 0.8375 - recall_2: 1.0000 - precision_2: 0.7547 - val_loss: 2.1349 - val_accuracy: 0.5000 - val_recall_2: 1.0000 - val_precision_2: 0.5000 - 10s/epoch - 10s/step
# Epoch 12/100
# 1/1 - 13s - loss: 1.1090 - accuracy: 0.6500 - recall_2: 1.0000 - precision_2: 0.5882 - val_loss: 2.2125 - val_accuracy: 0.5000 - val_recall_2: 1.0000 - val_precision_2: 0.5000 - 13s/epoch - 13s/step
# Epoch 13/100
# 1/1 - 10s - loss: 1.2209 - accuracy: 0.6375 - recall_2: 1.0000 - precision_2: 0.5797 - val_loss: 1.6585 - val_accuracy: 0.5500 - val_recall_2: 1.0000 - val_precision_2: 0.5263 - 10s/epoch - 10s/step
# Epoch 14/100
# 1/1 - 10s - loss: 0.7401 - accuracy: 0.7125 - recall_2: 1.0000 - precision_2: 0.6349 - val_loss: 0.9172 - val_accuracy: 0.5500 - val_recall_2: 0.7000 - val_precision_2: 0.5385 - 10s/epoch - 10s/step
# Epoch 15/100
# 1/1 - 10s - loss: 0.1993 - accuracy: 0.9125 - recall_2: 1.0000 - precision_2: 0.8511 - val_loss: 1.4618 - val_accuracy: 0.5500 - val_recall_2: 0.1000 - val_precision_2: 1.0000 - 10s/epoch - 10s/step
# Epoch 16/100
# 1/1 - 11s - loss: 0.3548 - accuracy: 0.8375 - recall_2: 0.7000 - precision_2: 0.9655 - val_loss: 2.0872 - val_accuracy: 0.5500 - val_recall_2: 0.1000 - val_precision_2: 1.0000 - 11s/epoch - 11s/step
# Epoch 17/100
# 1/1 - 10s - loss: 0.7224 - accuracy: 0.6500 - recall_2: 0.3000 - precision_2: 1.0000 - val_loss: 1.7544 - val_accuracy: 0.5500 - val_recall_2: 0.1000 - val_precision_2: 1.0000 - 10s/epoch - 10s/step
# Epoch 18/100
# 1/1 - 9s - loss: 0.5172 - accuracy: 0.7125 - recall_2: 0.4500 - precision_2: 0.9474 - val_loss: 1.2336 - val_accuracy: 0.5500 - val_recall_2: 0.2000 - val_precision_2: 0.6667 - 9s/epoch - 9s/step
# Epoch 19/100
# 1/1 - 10s - loss: 0.1563 - accuracy: 0.9500 - recall_2: 0.9250 - precision_2: 0.9737 - val_loss: 0.7503 - val_accuracy: 0.6500 - val_recall_2: 0.6000 - val_precision_2: 0.6667 - 10s/epoch - 10s/step
# Epoch 20/100
# 1/1 - 10s - loss: 0.1147 - accuracy: 0.9375 - recall_2: 1.0000 - precision_2: 0.8889 - val_loss: 0.8276 - val_accuracy: 0.6000 - val_recall_2: 1.0000 - val_precision_2: 0.5556 - 10s/epoch - 10s/step
# Epoch 21/100
# 1/1 - 11s - loss: 0.2267 - accuracy: 0.8875 - recall_2: 1.0000 - precision_2: 0.8163 - val_loss: 0.9543 - val_accuracy: 0.6500 - val_recall_2: 1.0000 - val_precision_2: 0.5882 - 11s/epoch - 11s/step
# Epoch 22/100
# 1/1 - 11s - loss: 0.2441 - accuracy: 0.9000 - recall_2: 1.0000 - precision_2: 0.8333 - val_loss: 1.1024 - val_accuracy: 0.6000 - val_recall_2: 1.0000 - val_precision_2: 0.5556 - 11s/epoch - 11s/step
# Epoch 23/100
# 1/1 - 10s - loss: 0.2686 - accuracy: 0.8750 - recall_2: 1.0000 - precision_2: 0.8000 - val_loss: 0.8317 - val_accuracy: 0.7000 - val_recall_2: 1.0000 - val_precision_2: 0.6250 - 10s/epoch - 10s/step
# Epoch 24/100
# 1/1 - 10s - loss: 0.1694 - accuracy: 0.9375 - recall_2: 1.0000 - precision_2: 0.8889 - val_loss: 0.5667 - val_accuracy: 0.7500 - val_recall_2: 1.0000 - val_precision_2: 0.6667 - 10s/epoch - 10s/step
# Epoch 25/100
# 1/1 - 10s - loss: 0.1241 - accuracy: 0.9500 - recall_2: 1.0000 - precision_2: 0.9091 - val_loss: 0.4976 - val_accuracy: 0.6500 - val_recall_2: 0.7000 - val_precision_2: 0.6364 - 10s/epoch - 10s/step
# Epoch 26/100
# 1/1 - 11s - loss: 0.0610 - accuracy: 0.9875 - recall_2: 1.0000 - precision_2: 0.9756 - val_loss: 0.5008 - val_accuracy: 0.7000 - val_recall_2: 0.4000 - val_precision_2: 1.0000 - 11s/epoch - 11s/step
# Epoch 27/100
# 1/1 - 10s - loss: 0.0732 - accuracy: 1.0000 - recall_2: 1.0000 - precision_2: 1.0000 - val_loss: 0.6086 - val_accuracy: 0.5500 - val_recall_2: 0.1000 - val_precision_2: 1.0000 - 10s/epoch - 10s/step
# Epoch 28/100
# 1/1 - 10s - loss: 0.1060 - accuracy: 1.0000 - recall_2: 1.0000 - precision_2: 1.0000 - val_loss: 0.7876 - val_accuracy: 0.7000 - val_recall_2: 0.4000 - val_precision_2: 1.0000 - 10s/epoch - 10s/step
# Epoch 29/100
# 1/1 - 10s - loss: 0.1225 - accuracy: 0.9625 - recall_2: 0.9250 - precision_2: 1.0000 - val_loss: 0.4922 - val_accuracy: 0.7000 - val_recall_2: 0.4000 - val_precision_2: 1.0000 - 10s/epoch - 10s/step
# Epoch 30/100
# 1/1 - 11s - loss: 0.1153 - accuracy: 0.9875 - recall_2: 0.9750 - precision_2: 1.0000 - val_loss: 0.4729 - val_accuracy: 0.7500 - val_recall_2: 0.5000 - val_precision_2: 1.0000 - 11s/epoch - 11s/step
# Epoch 31/100
# 1/1 - 10s - loss: 0.0553 - accuracy: 0.9875 - recall_2: 0.9750 - precision_2: 1.0000 - val_loss: 0.3124 - val_accuracy: 0.8500 - val_recall_2: 0.8000 - val_precision_2: 0.8889 - 10s/epoch - 10s/step
# Epoch 32/100
# 1/1 - 10s - loss: 0.0345 - accuracy: 1.0000 - recall_2: 1.0000 - precision_2: 1.0000 - val_loss: 0.2704 - val_accuracy: 0.9000 - val_recall_2: 1.0000 - val_precision_2: 0.8333 - 10s/epoch - 10s/step
# Epoch 33/100
# 1/1 - 10s - loss: 0.0306 - accuracy: 0.9875 - recall_2: 1.0000 - precision_2: 0.9756 - val_loss: 0.3078 - val_accuracy: 0.8500 - val_recall_2: 1.0000 - val_precision_2: 0.7692 - 10s/epoch - 10s/step
# Epoch 34/100
# 1/1 - 9s - loss: 0.0480 - accuracy: 0.9750 - recall_2: 1.0000 - precision_2: 0.9524 - val_loss: 0.2862 - val_accuracy: 0.9000 - val_recall_2: 1.0000 - val_precision_2: 0.8333 - 9s/epoch - 9s/step
# Epoch 35/100
# 1/1 - 12s - loss: 0.0427 - accuracy: 0.9875 - recall_2: 1.0000 - precision_2: 0.9756 - val_loss: 0.5490 - val_accuracy: 0.8000 - val_recall_2: 1.0000 - val_precision_2: 0.7143 - 12s/epoch - 12s/step
# Epoch 36/100
# 1/1 - 10s - loss: 0.0516 - accuracy: 0.9750 - recall_2: 1.0000 - precision_2: 0.9524 - val_loss: 0.4112 - val_accuracy: 0.8000 - val_recall_2: 1.0000 - val_precision_2: 0.7143 - 10s/epoch - 10s/step
# Epoch 37/100
# 1/1 - 10s - loss: 0.0505 - accuracy: 0.9625 - recall_2: 1.0000 - precision_2: 0.9302 - val_loss: 0.3293 - val_accuracy: 0.8500 - val_recall_2: 1.0000 - val_precision_2: 0.7692 - 10s/epoch - 10s/step
# Epoch 38/100
# 1/1 - 10s - loss: 0.0554 - accuracy: 0.9750 - recall_2: 1.0000 - precision_2: 0.9524 - val_loss: 0.2754 - val_accuracy: 0.8500 - val_recall_2: 1.0000 - val_precision_2: 0.7692 - 10s/epoch - 10s/step
# Epoch 39/100
# 1/1 - 10s - loss: 0.0225 - accuracy: 1.0000 - recall_2: 1.0000 - precision_2: 1.0000 - val_loss: 0.3257 - val_accuracy: 0.8500 - val_recall_2: 1.0000 - val_precision_2: 0.7692 - 10s/epoch - 10s/step
# Epoch 40/100
# 1/1 - 11s - loss: 0.0348 - accuracy: 1.0000 - recall_2: 1.0000 - precision_2: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9000 - val_recall_2: 1.0000 - val_precision_2: 0.8333 - 11s/epoch - 11s/step
# Epoch 41/100
#
# Akurasi di atas 97%, hentikan training!
# 1/1 - 11s - loss: 0.0168 - accuracy: 1.0000 - recall_2: 1.0000 - precision_2: 1.0000 - val_loss: 0.1124 - val_accuracy: 1.0000 - val_recall_2: 1.0000 - val_precision_2: 1.0000 - 11s/epoch - 11s/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Memprediksi probabilitas kelas positif
y_pred = model.predict(generator_valid)

# Mendapatkan label aktual dari data validasi
y_true = generator_valid.classes

# Menghitung nilai false positive rate (fpr) dan true positive rate (tpr) untuk kurva ROC
fpr, tpr, thresholds = roc_curve(y_true, y_pred)

# Menghitung AUC (Area Under the Curve) untuk kurva ROC
auc = roc_auc_score(y_true, y_pred)

# Menampilkan kurva ROC
plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], 'r--')
plt.title('Receiver Operating Characteristic (ROC)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
import matplotlib.pyplot as plt

# Mendapatkan nilai precision dan recall dari history
precision = history.history['precision_2']
recall = history.history['recall_2']

precision_val = history.history['val_precision_2']
recall_val = history.history['val_recall_2']


# Mengambil nilai terakhir dari list precision dan recall
final_precision = precision[-1]
final_recall = recall[-1]

final_precision_val = precision_val[-1]
final_recall_val = recall_val[-1]

# Menghitung F1-score
f1_score = 2 * (final_precision * final_recall) / (final_precision + final_recall)
f1_score_val = 2 * (final_precision_val * final_recall_val) / (final_precision_val + final_recall_val)

# Menampilkan nilai F1-score terakhir
print(f'Final F1-score: {f1_score:.2f}')
print(f'Final F1-score Validation: {f1_score_val:.2f}')
# Out:
# Final F1-score: 1.00
# Final F1-score Validation: 1.00

# %%
# Convert the model.
converter = tensor.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('daging_ayam_classification.tflite', 'wb') as f:
  f.write(tflite_model)

model.save('daging_ayam_classification.pb')
# !cd

# %%
model.save('daging_ayam_classification.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
