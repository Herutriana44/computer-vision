# %%
dataset = 'dataset/'
import os

# %% [markdown]
# ## Berikut adalah kodingan untuk klasifikasi menggunakan algoritma KNN

# %%
import numpy as np
import cv2
import os
import pickle
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
import joblib
import json

# Path to the dataset directory
data_dir = dataset

# List all image files in the dataset directory
image_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.jpg')]

# Load images and extract features
X = []
y = []
for image_file in image_files:
    img = cv2.imread(image_file)
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv_hist = cv2.calcHist([hsv_img], [0, 1, 2], None, [8, 2, 2], [0, 180, 0, 256, 0, 256])
    hsv_hist = cv2.normalize(hsv_hist, hsv_hist).flatten()
    X.append(hsv_hist)
    label = image_file.split('/')[-1].split('_')[0]
    # ubah label dari `mata ikan gak segar` menjadi 0 dan` mata ikan segar` menjadi 1
    if label == 'mata ikan gak segar':
        y.append(0)
    else:
        y.append(1)

# Convert data to numpy arrays
X = np.array(X)
y = np.array(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# KNN classification
knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(X_train, y_train)

# Save KNN model to file
pickle.dump(knn, open('KNN.pkl', 'wb'))

knn.save('KNN.h5')

# Evaluate KNN model
knn_preds = knn.predict(X_test)
knn_rmse = mean_squared_error(y_test, knn_preds, squared=False)
print('KNN RMSE:', knn_rmse)

# tampikan akurasinya
print('Akurasi KNN:', knn.score(X_test, y_test))

joblib.dump(knn, 'knn_model.pkl')
with open('knn_model.json', 'w') as f:
    f.write(json.dumps(joblib.load('knn_model.pkl').get_params()))
# Out:
# KNN RMSE: 0.1318760946791574
# Akurasi KNN: 0.9826086956521739

# %% [markdown]
# ## Berikut adalah kodingan untuk klasifikasi menggunakan algoritma CNN

# %%
import numpy as np
import cv2
import os
import pickle
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Reshape
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

# Path to the dataset directory
data_dir = dataset

# List all image files in the dataset directory
image_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.jpg')]

# Load images and extract features
X = []
y = []
for image_file in image_files:
    img = cv2.imread(image_file)
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv_hist = cv2.calcHist([hsv_img], [0, 1, 2], None, [8, 2, 2], [0, 180, 0, 256, 0, 256])
    hsv_hist = cv2.normalize(hsv_hist, hsv_hist).flatten()
    X.append(hsv_hist)
    label = image_file.split('/')[-1].split('_')[0]
    y.append(label)

# Convert data to numpy arrays
X = np.array(X)
y = np.array(y)

# ubah label dari `mata ikan gak segar` menjadi 0 dan` mata ikan segar` menjadi 1
y[y == 'mata ikan gak segar'] = 0
y[y == 'mata ikan segar'] = 1

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the CNN model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid',dtype='float32'))

# Compile the CNN model
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

unique_labels = np.unique(y_train)
print(unique_labels)
label_map = {label: i for i, label in enumerate(unique_labels)}
y_train = np.array([label_map[label] for label in y_train])

unique_labels = np.unique(y_test)
label_map = {label: i for i, label in enumerate(unique_labels)}
y_test = np.array([label_map[label] for label in y_test])

# Train the CNN model
model.fit(X_train, y_train, epochs=100, batch_size=32)

# Save the CNN model to file
model.save('CNN.h5')

# Evaluate the CNN model
cnn_preds = model.predict(X_test)
cnn_preds = np.round(cnn_preds).astype(int).flatten()
cnn_rmse = mean_squared_error(y_test, cnn_preds, squared=False)
print('CNN RMSE:', cnn_rmse)

# Save KNN model to file
pickle.dump(model, open('CNN.pkl', 'wb'))
# Export model to JSON file
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# ['0' '1']
# Epoch 1/100
# /home/herutriana44/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 44/44 [==============================] - 1s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5522
# Epoch 2/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 3/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 4/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 5/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 6/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 7/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 8/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 9/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 10/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 11/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 12/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 13/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 14/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 15/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 16/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 17/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 18/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 19/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 20/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 21/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 22/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 23/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 24/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 25/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 26/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 27/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 28/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 29/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 30/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 31/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 32/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 33/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 34/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 35/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 36/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 37/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 38/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 39/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 40/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 41/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 42/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 43/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 44/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 45/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 46/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 47/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 48/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 49/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 50/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 51/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 52/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 53/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 54/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 55/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 56/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 57/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 58/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 59/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 60/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 61/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 62/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 63/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 64/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 65/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 66/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 67/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 68/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 69/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 70/100
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 71/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 72/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 73/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 74/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 75/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 76/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 77/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 78/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 79/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 80/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 81/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 82/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 83/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 84/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 85/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 86/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 87/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 88/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 89/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 90/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 91/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 92/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 93/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 94/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 95/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 96/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 97/100
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 98/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 99/100
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# Epoch 100/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5552
# 11/11 [==============================] - 0s 2ms/step
# CNN RMSE: 0.6831300510639732
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ...metrics
# ......mean
# .........vars
# ............0
# ............1
# ......mean_metric_wrapper
# .........vars
# ............0
# ............1
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# variables.h5                                   2023-03-22 19:05:22        35392
# config.json                                    2023-03-22 19:05:22         2093
# metadata.json                                  2023-03-22 19:05:22           64

# %%
# save model ke pickle
import pickle
pickle.dump(model, open('CNN.pkl', 'wb'))
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ...metrics
# ......mean
# .........vars
# ............0
# ............1
# ......mean_metric_wrapper
# .........vars
# ............0
# ............1
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# variables.h5                                   2023-03-22 19:06:00        35392
# config.json                                    2023-03-22 19:06:00         2093
# metadata.json                                  2023-03-22 19:06:00           64
